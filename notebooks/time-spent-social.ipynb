# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/time-spent.csv')

# %%
df.head()
# Out:
#           Entity Code  Year  Mobile (BOND Internet Trends (2019))  \
# 0  United States  USA  2008                                   0.3
# 1  United States  USA  2009                                   0.3
# 2  United States  USA  2010                                   0.4
# 3  United States  USA  2011                                   0.8
# 4  United States  USA  2012                                   1.6
#
#    Desktop/Laptop (BOND Internet Trends (2019))  \
# 0                                           2.2
# 1                                           2.3
# 2                                           2.4
# 3                                           2.6
# 4                                           2.5
#
#    Other Connected Devices (BOND Internet Trends (2019))
# 0                                                0.2
# 1                                                0.3
# 2                                                0.4
# 3                                                0.3
# ...

# %%
# o comando df.shape mostra o número de linhas e colunas do DataFrame
print("linhas e colunas: ", df.shape)
# Out:
# linhas e colunas:  (11, 6)

# %%
# o comando df.isna() mostra os valores ausentes no DF, e o sum() soma esses valores por coluna
print(df.isna().sum())
# Out:
# Entity                                                   0
# Code                                                     0
# Year                                                     0
# Mobile (BOND Internet Trends (2019))                     0
# Desktop/Laptop (BOND Internet Trends (2019))             0
# Other Connected Devices (BOND Internet Trends (2019))    0
# dtype: int64

# %%
print(df.describe())
# Out:
#               Year  Mobile (BOND Internet Trends (2019))  \
# count    11.000000                             11.000000
# mean   2013.000000                              1.918182
# std       3.316625                              1.281264
# min    2008.000000                              0.300000
# 25%    2010.500000                              0.600000
# 50%    2013.000000                              2.300000
# 75%    2015.500000                              2.950000
# max    2018.000000                              3.600000
#
#        Desktop/Laptop (BOND Internet Trends (2019))  \
# count                                     11.000000
# mean                                       2.272727
# std                                        0.173729
# min                                        2.000000
# 25%                                        2.200000
# 50%                                        2.200000
# 75%                                        2.350000
# ...

# %%
# Criar o gráfico
plt.plot(df['Year'], df['Mobile (BOND Internet Trends (2019))'])

# Personalizar
plt.title('Gráfico - Tempo gasto em dispositivos móveis ao longo dos anos - EUA')
plt.xlabel('Ano')
plt.ylabel('Tempo em horas diárias')

plt.figtext(0.5, 0.01, 'BOND Internet Trends (2019) – processed by Our World in Data', 
            ha='center', fontsize=8, style='italic')

# Mostrar
plt.show()
